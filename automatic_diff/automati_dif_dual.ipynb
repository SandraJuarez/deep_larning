# %% [markdown]
# Automatic Differentiation
# =========================

# %%
import torch
import torchvision
import torchvision.transforms as transforms

# %%
# Cargar el conjunto de datos MNIST
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
train_dataset = torchvision.datasets.MNIST(root='./data', train=True, transform=transform, download=True)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=64, shuffle=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data\MNIST\raw\train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:04<00:00, 2208406.31it/s]
# Extracting ./data\MNIST\raw\train-images-idx3-ubyte.gz to ./data\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data\MNIST\raw\train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 4817294.75it/s]
# Extracting ./data\MNIST\raw\train-labels-idx1-ubyte.gz to ./data\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data\MNIST\raw\t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 2144345.42it/s]
# Extracting ./data\MNIST\raw\t10k-images-idx3-ubyte.gz to ./data\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data\MNIST\raw\t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<?, ?it/s]
# Extracting ./data\MNIST\raw\t10k-labels-idx1-ubyte.gz to ./data\MNIST\raw

# %% [markdown]
# Easy example of derivative with dual numbers
# ==========================

# %% [markdown]
# ![example](ejemplo.PNG)

# %%
# Definir números duales
class DualNumber:
    def __init__(self, real, dual):
        self.real = real
        self.dual = dual

    
def mul_dual(x,y):
    '''
    We need to define how we perform product in dual space
    '''
    return DualNumber(x.real@y.real,x.real@y.dual+x.dual@y.real)

def add_dual(x,y):
    return DualNumber(x.real+y.real,x.dual+y.dual)

# Función de activación sigmoide
def sigmoid(x):
    ''' 
    The real part will be the sigmoid and the dual part would be the analytic derivative of the sigmoid
    '''
    sig = 1.0 / (1.0 + torch.exp(-x.real))
    return DualNumber(sig, sig * (1.0 - sig) * x.dual)

# Entropía cruzada para múltiples clases
def cross_entropy_loss(predictions, targets):
    ''' 
    The real part will be the cross entropy and the dual part would be the analytic derivative of the ce
    '''
    #print('las predicciones son',predictions.real.shape)
    #print('las targets son',targets.shape)
    loss = -torch.sum(targets * torch.log(predictions.real + 1e-8))
    #print('la loss es',loss)
    loss_dual = -torch.sum(targets * (1.0 / (predictions.real + 1e-8)) * predictions.dual)
    #print('la loss dual es',loss_dual)
    return DualNumber(loss, loss_dual)

def softmax_with_dual(x_dual):
    ''' 
    The real part will be the softmax and the dual part would be the analytic derivative of the softmax
    '''
    exp_real = torch.exp(x_dual.real)
    sum_exp_real = torch.sum(exp_real, dim=1, keepdim=True)
    softmax_real = exp_real / sum_exp_real

    softmax_dual = (exp_real * (sum_exp_real - exp_real)) / (sum_exp_real * sum_exp_real) * x_dual.dual

    return DualNumber(softmax_real, softmax_dual)
    

# Definir una MLP simple con diferenciación automática
class SimpleMLP:
    def __init__(self, input_size, hidden_size, output_size):
        #the dual part of the weights is initialized as ones. 
        self.W1 = DualNumber(torch.randn(input_size, hidden_size), torch.ones(input_size, hidden_size))
        #self.b1 = DualNumber(torch.randn(1, hidden_size), torch.ones_like(1, hidden_size))
        self.W2 = DualNumber(torch.randn(hidden_size, output_size), torch.ones(hidden_size, output_size))
        #self.b2 = DualNumber(torch.randn(1, output_size), torch.ones_like(1, output_size))

    def forward(self, x):
        #the dual part of our samples are zeros because we are not interested in the derivatives with respect to x 
        x_dual = DualNumber(x, torch.zeros_like(x))  # Crear número dual para la entrada
        #it is like w@x
        z1 = mul_dual(x_dual,self.W1)
        #we activate it
        a1 = sigmoid(z1) #we utilize the sigmoid we defined, which gives us the dual part, which corresponds to the derivative

        #this part will te utilized to adjust the w1
        #here the dual part of the weights are set to zero because in the second part of the chain rule the variable 
        #see picture of example to see why
        z2_w1 = mul_dual(a1,DualNumber(self.W2.real,torch.zeros_like(self.W2.real)))
        #and this part to adjust the w2
        #here we need the a1 with the dual part as zeros because we are not interested in that derivative  to adjust w2
        z2_w2 = mul_dual(DualNumber(a1.real,torch.zeros_like(a1.real)),self.W2)
        a2_w1=softmax_with_dual(z2_w1)
        a2_w2=softmax_with_dual(z2_w2)      

        return a2_w1,a2_w2
    
    def zero_grad(self):
        self.W1.dual=torch.ones_like(self.W1.real)
        self.W2.dual=torch.ones_like(self.W2.real)
        return self.W1,self.W2

# %%
# Crear la MLP
input_size = 28 * 28
hidden_size = 128
output_size = 10
mlp = SimpleMLP(input_size, hidden_size, output_size)

# Entrenamiento simple usando diferenciación automática
learning_rate = 0.0000000000000000001
num_epochs = 7

for epoch in range(num_epochs):
    contador=0
    for images, labels in train_loader:
        images = images.view(-1, input_size)
        labels_onehot = torch.zeros(labels.size(0), output_size)
        labels_onehot.scatter_(1, labels.view(-1, 1), 1)

        #images_dual = DualNumber(images, torch.zeros_like(images))

        # Forward pass
        a2_w1,a2_w2 = mlp.forward(images)
        #print('salio de forward',contador, end='\r')
        #print('lo que salio de forward',a2_w1.dual, end='\r')
        contador+=1
        loss_w1 = cross_entropy_loss(a2_w1, labels_onehot)
        print('loss real',loss_w1.real)
        print('loss dual w1',loss_w1.dual)
        loss_w2 = cross_entropy_loss(a2_w2, labels_onehot)
        #print('loss real w2',loss_w2.real)
        #print('loss dual w2',loss_w2.dual)

        # Backpropagation
        #loss.real.backward()

        # Actualizar parámetros
        mlp.W1.real -= learning_rate * loss_w1.dual/64
        #mlp.W1.real -= 0 * loss_w1.dual

        #mlp.b1.real -= learning_rate * mlp.b1.real.grad
        mlp.W2.real -= 0 * loss_w2.dual/64
        #mlp.b2.real -= learning_rate * mlp.b2.real.grad

        # Limpiar duales de los pesos w
        mlp.zero_grad()
        #print('dual w1',mlp.W1.dual)
        

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss w1: {loss_w1.real.item()}, Loss w2: {loss_w2.real.item()}')
# Out:
# loss real tensor(894.8837)
# loss dual w1 tensor(270.2663)
# loss real tensor(919.9730)
# loss dual w1 tensor(2602.7659)
# loss real tensor(859.0394)
# loss dual w1 tensor(282.1953)
# loss real tensor(918.1414)
# loss dual w1 tensor(-1447.6689)
# loss real tensor(958.4288)
# loss dual w1 tensor(1526.1520)
# loss real tensor(946.1744)
# loss dual w1 tensor(2157.1963)
# loss real tensor(847.3157)
# loss dual w1 tensor(343.2097)
# loss real tensor(862.3750)
# loss dual w1 tensor(-1753.5132)
# loss real tensor(871.6534)
# loss dual w1 tensor(-38.9536)
# loss real tensor(812.1541)
# loss dual w1 tensor(1697.7244)
# loss real tensor(911.8663)
# loss dual w1 tensor(-555.9580)
# loss real tensor(875.0541)
# loss dual w1 tensor(2155.1931)
# loss real tensor(879.2654)
# loss dual w1 tensor(2106.4673)
# loss real tensor(779.1421)
# loss dual w1 tensor(780.0670)
# loss real tensor(873.3259)
# loss dual w1 tensor(-1641.6405)
# loss real tensor(883.1443)
# loss dual w1 tensor(-248.7106)
# loss real tensor(831.0110)
# loss dual w1 tensor(3174.1633)
# loss real tensor(990.1582)
# loss dual w1 tensor(-1341.7070)
# loss real tensor(876.8418)
# loss dual w1 tensor(1126.5541)
# loss real tensor(908.2426)
# loss dual w1 tensor(-1153.2451)
# loss real tensor(930.3993)
# loss dual w1 tensor(-1197.6250)
# loss real tensor(963.2089)
# loss dual w1 tensor(1958.2887)
# loss real tensor(826.2579)
# loss dual w1 tensor(932.2191)
# loss real tensor(897.2480)
# loss dual w1 tensor(2275.4458)
# loss real tensor(861.0074)
# loss dual w1 tensor(1117.7036)
# loss real tensor(885.4620)
# loss dual w1 tensor(1735.8871)
# loss real tensor(892.2134)
# loss dual w1 tensor(-1714.5457)
# loss real tensor(903.4672)
# loss dual w1 tensor(344.1064)
# loss real tensor(951.2173)
# loss dual w1 tensor(58.9578)
# loss real tensor(903.3231)
# loss dual w1 tensor(309.6290)
# loss real tensor(940.6114)
# loss dual w1 tensor(-1464.3748)
# loss real tensor(836.4047)
# loss dual w1 tensor(1190.0671)
# loss real tensor(907.8106)
# loss dual w1 tensor(3917.2754)
# loss real tensor(927.4025)
# loss dual w1 tensor(-973.5647)
# loss real tensor(727.9779)
# loss dual w1 tensor(-377.2134)
# loss real tensor(889.0617)
# loss dual w1 tensor(498.4026)
# loss real tensor(934.2645)
# loss dual w1 tensor(3994.4902)
# loss real tensor(861.2460)
# loss dual w1 tensor(69.9494)
# loss real tensor(911.5586)
# loss dual w1 tensor(1116.1179)
# loss real tensor(961.4713)
# loss dual w1 tensor(1682.9199)
# loss real tensor(919.3947)
# loss dual w1 tensor(-1841.7516)
# loss real tensor(871.1211)
# loss dual w1 tensor(3515.3521)
# loss real tensor(855.3621)
# loss dual w1 tensor(821.0911)
# loss real tensor(944.2585)
# loss dual w1 tensor(670.9924)
# loss real tensor(822.8281)
# loss dual w1 tensor(1320.4270)
# loss real tensor(889.9519)
# loss dual w1 tensor(600.0215)
# loss real tensor(905.3538)
# loss dual w1 tensor(3950.5857)
# loss real tensor(883.7467)
# loss dual w1 tensor(-381.9381)
# loss real tensor(859.0399)
# loss dual w1 tensor(296.3146)
# loss real tensor(886.6283)
# loss dual w1 tensor(790.7897)
# loss real tensor(851.6614)
# loss dual w1 tensor(1435.9171)
# loss real tensor(817.4468)
# loss dual w1 tensor(7.2927)
# loss real tensor(901.4338)
# loss dual w1 tensor(1844.5740)
# loss real tensor(855.8658)
# loss dual w1 tensor(651.1270)
# loss real tensor(913.2704)
# loss dual w1 tensor(-312.9212)
# loss real tensor(850.1932)
# loss dual w1 tensor(-1414.1106)
# loss real tensor(882.3768)
# loss dual w1 tensor(3124.6436)
# loss real tensor(1010.6909)
# loss dual w1 tensor(360.7764)
# loss real tensor(757.3127)
# loss dual w1 tensor(-151.8361)
# loss real tensor(972.3026)
# loss dual w1 tensor(-306.6622)
# loss real tensor(903.4248)
# loss dual w1 tensor(1108.5118)
# loss real tensor(919.6004)
# loss dual w1 tensor(2277.8704)
# loss real tensor(950.7725)
# loss dual w1 tensor(-412.6993)
# loss real tensor(846.5809)
# loss dual w1 tensor(-2213.8379)
# loss real tensor(939.0211)
# loss dual w1 tensor(-75.1498)
# loss real tensor(920.2864)
# loss dual w1 tensor(-852.9893)
# loss real tensor(933.5092)
# loss dual w1 tensor(-632.0698)
# loss real tensor(973.0356)
# loss dual w1 tensor(679.1489)
# loss real tensor(889.4106)
# loss dual w1 tensor(-493.3585)
# loss real tensor(930.3878)
# loss dual w1 tensor(15.4994)
# loss real tensor(990.5858)
# loss dual w1 tensor(1492.1572)
# loss real tensor(980.0217)
# loss dual w1 tensor(-1157.0145)
# loss real tensor(882.9185)
# loss dual w1 tensor(64.1874)
# loss real tensor(962.0211)
# loss dual w1 tensor(209.6083)
# loss real tensor(884.9401)
# loss dual w1 tensor(2723.9214)
# loss real tensor(871.0314)
# loss dual w1 tensor(2785.4863)
# loss real tensor(937.0879)
# loss dual w1 tensor(841.5263)
# loss real tensor(848.4938)
# loss dual w1 tensor(970.6136)
# loss real tensor(910.5900)
# loss dual w1 tensor(491.0291)
# loss real tensor(778.9705)
# loss dual w1 tensor(-366.4465)
# loss real tensor(907.0844)
# loss dual w1 tensor(-1838.5723)
# loss real tensor(976.7127)
# loss dual w1 tensor(-1560.9514)
# loss real tensor(894.0714)
# loss dual w1 tensor(2305.5425)
# loss real tensor(925.2908)
# loss dual w1 tensor(632.8328)
# loss real tensor(898.8877)
# loss dual w1 tensor(-1433.0829)
# loss real tensor(930.9138)
# loss dual w1 tensor(92.0373)
# loss real tensor(860.7559)
# loss dual w1 tensor(1869.9147)
# loss real tensor(913.4858)
# loss dual w1 tensor(2368.4419)
# loss real tensor(838.4261)
# loss dual w1 tensor(591.5024)
# loss real tensor(931.1124)
# loss dual w1 tensor(-345.8739)
# loss real tensor(903.1628)
# loss dual w1 tensor(2845.0269)
# loss real tensor(894.2209)
# loss dual w1 tensor(-192.9899)
# loss real tensor(936.9504)
# loss dual w1 tensor(67.0316)
# loss real tensor(867.7081)
# loss dual w1 tensor(-58.6802)
# loss real tensor(852.9127)
# loss dual w1 tensor(2617.8545)
# loss real tensor(972.4191)
# loss dual w1 tensor(928.5840)
# loss real tensor(907.3014)
# loss dual w1 tensor(531.8619)
# loss real tensor(926.1352)
# loss dual w1 tensor(2966.4924)
# loss real tensor(883.7646)
# loss dual w1 tensor(29.9476)
# loss real tensor(844.8176)
# loss dual w1 tensor(390.9896)
# loss real tensor(938.9086)
# loss dual w1 tensor(424.6797)
# loss real tensor(999.0421)
# loss dual w1 tensor(389.9346)
# loss real tensor(884.0215)
# loss dual w1 tensor(1962.5178)
# loss real tensor(902.8336)
# loss dual w1 tensor(1086.2666)
# loss real tensor(886.8346)
# loss dual w1 tensor(1393.2229)
# loss real tensor(903.6572)
# loss dual w1 tensor(2308.0647)
# loss real tensor(892.3412)
# loss dual w1 tensor(878.9613)
# loss real tensor(948.0563)
# loss dual w1 tensor(1663.5527)
# loss real tensor(837.4330)
# loss dual w1 tensor(2128.8364)
# loss real tensor(907.9524)
# loss dual w1 tensor(-885.5905)
# loss real tensor(936.8915)
# loss dual w1 tensor(332.4743)
# loss real tensor(905.5056)
# loss dual w1 tensor(462.5684)
# loss real tensor(906.7090)
# loss dual w1 tensor(1916.8787)
# loss real tensor(835.7736)
# loss dual w1 tensor(809.1817)
# loss real tensor(938.4456)
# loss dual w1 tensor(-1538.4380)
# loss real tensor(849.6121)
# loss dual w1 tensor(1639.8855)
# loss real tensor(917.3919)
# loss dual w1 tensor(886.8009)
# loss real tensor(831.9075)
# loss dual w1 tensor(832.7823)
# loss real tensor(918.7258)
# loss dual w1 tensor(2440.2632)
# loss real tensor(858.0065)
# loss dual w1 tensor(2277.7334)
# loss real tensor(842.2173)
# loss dual w1 tensor(3361.3567)
# loss real tensor(836.3060)
# loss dual w1 tensor(1789.3557)
# loss real tensor(928.8865)
# loss dual w1 tensor(-2530.4780)
# loss real tensor(853.6326)
# loss dual w1 tensor(2222.8450)
# loss real tensor(811.8931)
# loss dual w1 tensor(2506.6040)
# loss real tensor(877.6568)
# loss dual w1 tensor(452.7570)
# loss real tensor(918.9290)
# loss dual w1 tensor(4001.2007)
# loss real tensor(890.6902)
# loss dual w1 tensor(1479.0986)
# loss real tensor(947.2339)
# loss dual w1 tensor(-1510.9489)
# loss real tensor(859.8506)
# loss dual w1 tensor(3359.8054)
# loss real tensor(909.6193)
# loss dual w1 tensor(1059.9154)
# loss real tensor(924.1663)
# loss dual w1 tensor(-118.3704)
# loss real tensor(893.3312)
# loss dual w1 tensor(3530.5635)
# loss real tensor(872.1649)
# loss dual w1 tensor(-1642.2664)
# loss real tensor(801.5374)
# loss dual w1 tensor(4038.8586)
# loss real tensor(999.6703)
# loss dual w1 tensor(173.8694)
# loss real tensor(876.5580)
# loss dual w1 tensor(646.2861)
# loss real tensor(837.4832)
# loss dual w1 tensor(3208.0972)
# loss real tensor(899.0952)
# loss dual w1 tensor(321.2058)
# loss real tensor(891.4972)
# loss dual w1 tensor(1912.1943)
# loss real tensor(905.2312)
# loss dual w1 tensor(2542.2510)
# loss real tensor(867.7564)
# loss dual w1 tensor(-2896.6826)
# loss real tensor(874.0162)
# loss dual w1 tensor(1291.0413)
# loss real tensor(934.6998)
# loss dual w1 tensor(1018.9026)
# loss real tensor(899.3086)
# loss dual w1 tensor(2981.7869)
# loss real tensor(883.7231)
# loss dual w1 tensor(1614.0709)
# loss real tensor(933.3680)
# loss dual w1 tensor(-1408.6725)
# loss real tensor(948.2876)
# loss dual w1 tensor(159.2552)
# loss real tensor(901.4449)
# loss dual w1 tensor(2759.8948)
# loss real tensor(908.5829)
# loss dual w1 tensor(266.9088)
# loss real tensor(831.3456)
# loss dual w1 tensor(2687.0332)
# loss real tensor(873.1538)
# loss dual w1 tensor(2897.6824)
# loss real tensor(836.8771)
# loss dual w1 tensor(-304.6875)
# loss real tensor(852.3046)
# loss dual w1 tensor(1902.8734)
# loss real tensor(831.1644)
# loss dual w1 tensor(3773.7173)
# loss real tensor(925.4644)
# loss dual w1 tensor(-435.5096)
# loss real tensor(813.9187)
# loss dual w1 tensor(1259.3218)
# loss real tensor(834.0797)
# loss dual w1 tensor(-1595.2872)
# loss real tensor(902.0007)
# loss dual w1 tensor(-485.6259)
# loss real tensor(795.0559)
# loss dual w1 tensor(1794.1776)
# loss real tensor(936.5360)
# loss dual w1 tensor(-1974.9331)
# loss real tensor(881.8345)
# loss dual w1 tensor(825.8237)
# loss real tensor(888.9704)
# loss dual w1 tensor(-1286.2496)
# loss real tensor(827.3251)
# loss dual w1 tensor(-2648.2092)
# loss real tensor(860.2642)
# loss dual w1 tensor(-2295.1550)
# loss real tensor(975.7863)
# loss dual w1 tensor(-3203.1665)
# loss real tensor(921.1996)
# loss dual w1 tensor(-4.9830)
# loss real tensor(849.8308)
# loss dual w1 tensor(-53.0399)
# loss real tensor(841.3879)
# loss dual w1 tensor(-929.0981)
# loss real tensor(779.3651)
# loss dual w1 tensor(2684.7368)
# loss real tensor(939.1773)
# loss dual w1 tensor(1143.4451)
# loss real tensor(897.6469)
# loss dual w1 tensor(2934.0913)
# loss real tensor(890.3440)
# loss dual w1 tensor(620.5536)
# loss real tensor(872.8520)
# loss dual w1 tensor(-254.1151)
# loss real tensor(912.2477)
# loss dual w1 tensor(2914.0723)
# loss real tensor(888.2184)
# loss dual w1 tensor(646.4934)
# loss real tensor(973.0347)
# loss dual w1 tensor(986.0621)
# loss real tensor(797.7183)
# loss dual w1 tensor(600.8760)
# loss real tensor(813.3475)
# loss dual w1 tensor(1988.9529)
# loss real tensor(928.3807)
# loss dual w1 tensor(-782.5442)
# loss real tensor(883.6350)
# loss dual w1 tensor(197.4323)
# loss real tensor(893.6351)
# loss dual w1 tensor(1680.3542)
# loss real tensor(886.3463)
# loss dual w1 tensor(913.3524)
# loss real tensor(880.7686)
# loss dual w1 tensor(3115.5779)
# loss real tensor(847.0944)
# loss dual w1 tensor(2019.6694)
# loss real tensor(806.0864)
# loss dual w1 tensor(3240.8638)
# loss real tensor(899.4927)
# loss dual w1 tensor(-1197.0708)
# loss real tensor(946.1205)
# loss dual w1 tensor(672.6243)
# loss real tensor(952.9772)
# loss dual w1 tensor(393.3625)
# loss real tensor(862.7790)
# loss dual w1 tensor(-103.1793)
# loss real tensor(921.4967)
# loss dual w1 tensor(-903.4694)
# loss real tensor(869.8934)
# loss dual w1 tensor(1521.7444)
# loss real tensor(880.5579)
# loss dual w1 tensor(-1009.7285)
# loss real tensor(965.5736)
# loss dual w1 tensor(-895.3565)
# loss real tensor(850.0228)
# loss dual w1 tensor(1515.4885)
# loss real tensor(911.6096)
# loss dual w1 tensor(3997.4209)
# loss real tensor(925.6742)
# loss dual w1 tensor(1249.1248)
# loss real tensor(879.9117)
# loss dual w1 tensor(-577.7693)
# loss real tensor(848.2735)
# loss dual w1 tensor(2884.4294)
# loss real tensor(831.8832)
# loss dual w1 tensor(-1543.8928)
# loss real tensor(850.1781)
# loss dual w1 tensor(-745.7011)
# loss real tensor(994.3668)
# loss dual w1 tensor(-48.1713)
# loss real tensor(901.4616)
# loss dual w1 tensor(-730.7092)
# loss real tensor(985.1116)
# loss dual w1 tensor(598.3616)
# loss real tensor(815.8333)
# loss dual w1 tensor(104.9252)
# loss real tensor(776.2120)
# loss dual w1 tensor(-1781.8164)
# loss real tensor(906.1819)
# loss dual w1 tensor(1044.1830)
# loss real tensor(885.8650)
# loss dual w1 tensor(1279.0967)
# loss real tensor(852.9048)
# loss dual w1 tensor(1953.5570)
# loss real tensor(927.0187)
# loss dual w1 tensor(356.6446)
# loss real tensor(902.1412)
# loss dual w1 tensor(-915.2936)
# loss real tensor(946.5776)
# loss dual w1 tensor(227.3788)
# loss real tensor(752.3484)
# loss dual w1 tensor(142.3680)
# loss real tensor(826.0971)
# loss dual w1 tensor(1780.5691)
# loss real tensor(915.7563)
# loss dual w1 tensor(-314.3000)
# loss real tensor(940.8511)
# loss dual w1 tensor(292.8403)
# loss real tensor(945.1672)
# loss dual w1 tensor(-303.5261)
# loss real tensor(920.4628)
# loss dual w1 tensor(2208.7866)
# loss real tensor(838.8724)
# loss dual w1 tensor(336.3257)
# loss real tensor(930.7145)
# loss dual w1 tensor(1214.0139)
# loss real tensor(874.5796)
# loss dual w1 tensor(-249.4058)
# loss real tensor(985.3502)
# loss dual w1 tensor(1647.9678)
# loss real tensor(850.9492)
# loss dual w1 tensor(1969.5826)
# loss real tensor(934.7419)
# loss dual w1 tensor(-243.5507)
# loss real tensor(804.7454)
# loss dual w1 tensor(2498.6289)
# loss real tensor(884.6748)
# loss dual w1 tensor(-32.6621)
# loss real tensor(884.3183)
# loss dual w1 tensor(2055.0576)
# loss real tensor(925.8996)
# loss dual w1 tensor(1176.7350)
# loss real tensor(827.1843)
# loss dual w1 tensor(-2429.3643)
# loss real tensor(852.5460)
# loss dual w1 tensor(1351.9943)
# loss real tensor(877.2216)
# loss dual w1 tensor(956.1000)
# loss real tensor(922.2462)
# loss dual w1 tensor(-189.6587)
# loss real tensor(866.8298)
# loss dual w1 tensor(1077.2916)
# loss real tensor(879.8806)
# loss dual w1 tensor(-2743.7480)
# loss real tensor(898.8705)
# loss dual w1 tensor(506.9166)
# loss real tensor(890.5510)
# loss dual w1 tensor(1934.5388)
# loss real tensor(884.7722)
# loss dual w1 tensor(-290.1379)
# loss real tensor(815.1289)
# loss dual w1 tensor(901.3499)
# loss real tensor(804.5404)
# loss dual w1 tensor(-41.2139)
# loss real tensor(936.1624)
# loss dual w1 tensor(2258.4448)
# loss real tensor(798.2453)
# loss dual w1 tensor(311.8106)
# loss real tensor(921.2576)
# loss dual w1 tensor(104.2661)
# loss real tensor(856.4023)
# loss dual w1 tensor(1223.6642)
# loss real tensor(911.4364)
# loss dual w1 tensor(1110.8959)
# loss real tensor(835.6305)
# loss dual w1 tensor(-801.8009)
# loss real tensor(854.5760)
# loss dual w1 tensor(702.8578)
# loss real tensor(861.6597)
# loss dual w1 tensor(392.6665)
# loss real tensor(952.1196)
# loss dual w1 tensor(1449.8379)
# loss real tensor(861.2386)
# loss dual w1 tensor(1418.8438)
# loss real tensor(908.0666)
# loss dual w1 tensor(-905.4969)
# loss real tensor(832.2418)
# loss dual w1 tensor(4838.7363)
# loss real tensor(848.1498)
# loss dual w1 tensor(1104.2362)
# loss real tensor(895.8828)
# loss dual w1 tensor(2808.0940)
# loss real tensor(873.1068)
# loss dual w1 tensor(349.7877)
# loss real tensor(891.3565)
# loss dual w1 tensor(2221.7944)
# loss real tensor(885.4283)
# loss dual w1 tensor(2093.2576)
# loss real tensor(887.7933)
# loss dual w1 tensor(-2201.8962)
# loss real tensor(887.0745)
# loss dual w1 tensor(2820.1335)
# loss real tensor(983.6101)
# loss dual w1 tensor(2613.5959)
# loss real tensor(892.8578)
# loss dual w1 tensor(1771.2764)
# loss real tensor(897.2292)
# loss dual w1 tensor(4161.4634)
# loss real tensor(922.2908)
# loss dual w1 tensor(72.2664)
# loss real tensor(839.3914)
# loss dual w1 tensor(2961.2056)
# loss real tensor(873.5732)
# loss dual w1 tensor(1827.5679)
# loss real tensor(938.6665)
# loss dual w1 tensor(1886.0334)
# loss real tensor(940.6285)
# loss dual w1 tensor(-33.1444)
# loss real tensor(873.1899)
# loss dual w1 tensor(1880.0854)
# loss real tensor(924.0229)
# loss dual w1 tensor(218.3934)
# loss real tensor(922.3889)
# loss dual w1 tensor(1169.0625)
# loss real tensor(801.6923)
# loss dual w1 tensor(342.5305)
# loss real tensor(898.9841)
# loss dual w1 tensor(2287.6145)
# loss real tensor(887.9752)
# loss dual w1 tensor(1895.2509)
# loss real tensor(864.2823)
# loss dual w1 tensor(-1077.1473)
# loss real tensor(856.2145)
# loss dual w1 tensor(5088.1523)
# loss real tensor(925.8771)
# loss dual w1 tensor(850.3998)
# loss real tensor(952.5073)
# loss dual w1 tensor(2390.6770)
# loss real tensor(816.2646)
# loss dual w1 tensor(779.2808)
# loss real tensor(912.6122)
# loss dual w1 tensor(-635.0568)
# loss real tensor(896.4161)
# loss dual w1 tensor(-2056.3628)
# loss real tensor(948.6553)
# loss dual w1 tensor(890.7319)
# loss real tensor(793.9753)
# loss dual w1 tensor(1.2616)
# loss real tensor(839.6407)
# loss dual w1 tensor(-1904.0186)
# loss real tensor(956.0959)
# loss dual w1 tensor(1293.8750)
# loss real tensor(833.0077)
# loss dual w1 tensor(194.7881)
# loss real tensor(874.6048)
# loss dual w1 tensor(1026.6143)
# loss real tensor(863.7728)
# loss dual w1 tensor(3728.9155)
# loss real tensor(815.8991)
# loss dual w1 tensor(-215.2406)
# loss real tensor(958.0671)
# loss dual w1 tensor(2460.5964)
# loss real tensor(859.4230)
# loss dual w1 tensor(-1250.1696)
# loss real tensor(905.4375)
# loss dual w1 tensor(1272.9127)
# loss real tensor(883.1434)
# loss dual w1 tensor(-167.7415)
# loss real tensor(937.0804)
# loss dual w1 tensor(-1041.4918)
# loss real tensor(880.3416)
# loss dual w1 tensor(-746.5518)
# loss real tensor(899.9027)
# loss dual w1 tensor(759.2356)
# loss real tensor(856.1477)
# loss dual w1 tensor(-455.9227)
# loss real tensor(916.1868)
# loss dual w1 tensor(3387.5044)
# loss real tensor(895.9722)
# loss dual w1 tensor(1874.2983)
# loss real tensor(966.1550)
# loss dual w1 tensor(2690.8735)
# loss real tensor(776.8990)
# loss dual w1 tensor(979.3889)
# loss real tensor(893.1511)
# loss dual w1 tensor(-586.1427)
# loss real tensor(871.2708)
# loss dual w1 tensor(1888.8138)
# loss real tensor(917.3099)
# loss dual w1 tensor(-1604.3630)
# loss real tensor(940.5414)
# loss dual w1 tensor(-469.5972)
# loss real tensor(864.5558)
# loss dual w1 tensor(1240.4779)
# loss real tensor(877.6751)
# loss dual w1 tensor(1284.3594)
# loss real tensor(781.1350)
# loss dual w1 tensor(-1405.3821)
# loss real tensor(864.1308)
# loss dual w1 tensor(3332.2029)
# loss real tensor(816.9423)
# loss dual w1 tensor(1158.7343)
# loss real tensor(854.5378)
# loss dual w1 tensor(2884.4521)
# loss real tensor(925.8677)
# loss dual w1 tensor(-1486.3337)
# loss real tensor(811.2985)
# loss dual w1 tensor(-1136.2627)
# loss real tensor(879.4009)
# loss dual w1 tensor(308.8317)
# loss real tensor(786.0568)
# loss dual w1 tensor(-25.8215)
# loss real tensor(927.8718)
# loss dual w1 tensor(1195.8638)
# loss real tensor(866.8724)
# loss dual w1 tensor(-20.2057)
# loss real tensor(874.0187)
# loss dual w1 tensor(-39.7065)
# loss real tensor(926.9794)
# loss dual w1 tensor(-2011.8752)
# loss real tensor(828.3597)
# loss dual w1 tensor(1368.6060)
# loss real tensor(851.9557)
# loss dual w1 tensor(17.9480)
# loss real tensor(931.5174)
# loss dual w1 tensor(1457.9382)
# loss real tensor(909.0983)
# loss dual w1 tensor(12.1323)
# loss real tensor(957.9974)
# loss dual w1 tensor(612.4105)
# loss real tensor(876.6127)
# loss dual w1 tensor(1430.9545)
# loss real tensor(855.7000)
# loss dual w1 tensor(1206.1533)
# loss real tensor(872.1065)
# loss dual w1 tensor(2700.9541)
# loss real tensor(869.6812)
# loss dual w1 tensor(1362.6819)
# loss real tensor(827.4378)
# loss dual w1 tensor(4746.9072)
# loss real tensor(947.7863)
# loss dual w1 tensor(1142.6656)
# loss real tensor(859.5128)
# loss dual w1 tensor(3230.3936)
# loss real tensor(855.7181)
# loss dual w1 tensor(-822.0969)
# loss real tensor(787.1528)
# loss dual w1 tensor(1904.1676)
# loss real tensor(855.1711)
# loss dual w1 tensor(290.9857)
# loss real tensor(836.8492)
# loss dual w1 tensor(1695.4958)
# loss real tensor(874.8059)
# loss dual w1 tensor(-96.6006)
# loss real tensor(913.5128)
# loss dual w1 tensor(-1033.1709)
# loss real tensor(943.6877)
# loss dual w1 tensor(-971.2820)
# loss real tensor(933.3226)
# loss dual w1 tensor(1070.6682)
# loss real tensor(933.8834)
# loss dual w1 tensor(1400.6388)
# loss real tensor(975.9291)
# loss dual w1 tensor(-275.6049)
# loss real tensor(892.0560)
# loss dual w1 tensor(823.2384)
# loss real tensor(953.8649)
# loss dual w1 tensor(1104.7273)
# loss real tensor(835.2930)
# loss dual w1 tensor(135.6258)
# loss real tensor(931.9980)
# loss dual w1 tensor(-994.7137)
# loss real tensor(1020.6923)
# loss dual w1 tensor(-681.6564)
# loss real tensor(896.1255)
# loss dual w1 tensor(2267.3005)
# loss real tensor(966.2169)
# loss dual w1 tensor(-401.1005)
# loss real tensor(897.4699)
# loss dual w1 tensor(-2835.7979)
# loss real tensor(825.4073)
# loss dual w1 tensor(-416.0717)
# loss real tensor(817.4562)
# loss dual w1 tensor(1771.0975)
# loss real tensor(915.4050)
# loss dual w1 tensor(146.1569)
# loss real tensor(957.6737)
# loss dual w1 tensor(580.9456)
# loss real tensor(862.5001)
# loss dual w1 tensor(-1164.8877)
# loss real tensor(838.6814)
# loss dual w1 tensor(-220.9418)
# loss real tensor(894.8586)
# loss dual w1 tensor(687.0927)
# loss real tensor(836.5528)
# loss dual w1 tensor(550.3243)
# loss real tensor(939.9842)
# loss dual w1 tensor(-430.3776)
# loss real tensor(880.6660)
# loss dual w1 tensor(457.9284)
# loss real tensor(870.9470)
# loss dual w1 tensor(983.0343)
# loss real tensor(904.9746)
# loss dual w1 tensor(-45.9696)
# loss real tensor(826.9918)
# loss dual w1 tensor(176.6218)
# loss real tensor(837.4934)
# loss dual w1 tensor(3086.9722)
# loss real tensor(894.4516)
# loss dual w1 tensor(1014.5387)
# loss real tensor(948.6155)
# loss dual w1 tensor(-56.2863)
# loss real tensor(879.1140)
# loss dual w1 tensor(69.4891)
# loss real tensor(952.0449)
# loss dual w1 tensor(-447.4924)
# loss real tensor(907.8433)
# loss dual w1 tensor(-1022.3464)
# loss real tensor(855.8094)
# loss dual w1 tensor(-429.2413)
# loss real tensor(904.9725)
# loss dual w1 tensor(-1330.7981)
# loss real tensor(858.7753)
# loss dual w1 tensor(2559.0959)
# loss real tensor(832.9359)
# loss dual w1 tensor(2347.7881)
# loss real tensor(847.3873)
# loss dual w1 tensor(-921.8033)
# loss real tensor(856.7672)
# loss dual w1 tensor(3529.5366)
# loss real tensor(889.9633)
# loss dual w1 tensor(1569.7837)
# loss real tensor(824.8529)
# loss dual w1 tensor(1097.8579)
# loss real tensor(874.0216)
# loss dual w1 tensor(804.7366)
# loss real tensor(827.0773)
# loss dual w1 tensor(466.3042)
# loss real tensor(887.9921)
# loss dual w1 tensor(1765.4973)
# loss real tensor(893.8121)
# loss dual w1 tensor(3561.6150)
# loss real tensor(917.4254)
# loss dual w1 tensor(769.8358)
# loss real tensor(812.5031)
# loss dual w1 tensor(-2339.9724)
# loss real tensor(831.5520)
# loss dual w1 tensor(2483.4421)
# loss real tensor(944.5314)
# loss dual w1 tensor(-681.6122)
# loss real tensor(833.3478)
# loss dual w1 tensor(-23.9608)
# loss real tensor(854.4414)
# loss dual w1 tensor(-982.6877)
# loss real tensor(863.4821)
# loss dual w1 tensor(101.2574)
# loss real tensor(918.3328)
# loss dual w1 tensor(-1438.3032)
# loss real tensor(960.8570)
# loss dual w1 tensor(-45.4939)
# loss real tensor(811.2707)
# loss dual w1 tensor(2720.6636)
# loss real tensor(839.3430)
# loss dual w1 tensor(2013.8975)
# loss real tensor(824.4944)
# loss dual w1 tensor(-1164.5410)
# loss real tensor(773.2073)
# loss dual w1 tensor(1486.4661)
# loss real tensor(828.5856)
# loss dual w1 tensor(3367.0923)
# loss real tensor(835.8259)
# loss dual w1 tensor(-543.6994)
# loss real tensor(843.6007)
# loss dual w1 tensor(1802.7466)
# loss real tensor(825.4320)
# loss dual w1 tensor(183.1468)
# loss real tensor(992.2391)
# loss dual w1 tensor(-977.9756)
# loss real tensor(855.0914)
# loss dual w1 tensor(1323.3979)
# loss real tensor(844.5632)
# loss dual w1 tensor(-177.3330)
# loss real tensor(787.0715)
# loss dual w1 tensor(3335.4490)
# loss real tensor(893.6995)
# loss dual w1 tensor(2740.4343)
# loss real tensor(904.8437)
# loss dual w1 tensor(2313.7283)
# loss real tensor(877.6852)
# loss dual w1 tensor(-232.4783)
# loss real tensor(910.1169)
# loss dual w1 tensor(1338.0408)
# loss real tensor(975.5707)
# loss dual w1 tensor(-686.5188)
# loss real tensor(858.9163)
# loss dual w1 tensor(2377.5635)
# loss real tensor(951.4622)
# loss dual w1 tensor(1988.6492)
# loss real tensor(894.3984)
# loss dual w1 tensor(1807.5834)
# loss real tensor(965.0764)
# loss dual w1 tensor(2754.6763)
# loss real tensor(936.1775)
# loss dual w1 tensor(-751.8013)
# loss real tensor(855.5320)
# loss dual w1 tensor(2667.3657)
# loss real tensor(850.2550)
# loss dual w1 tensor(534.8984)
# loss real tensor(906.8676)
# loss dual w1 tensor(377.7659)
# loss real tensor(894.4611)
# loss dual w1 tensor(838.0636)
# loss real tensor(840.9153)
# loss dual w1 tensor(-1826.5060)
# loss real tensor(980.4305)
# loss dual w1 tensor(1495.3590)
# loss real tensor(906.5323)
# loss dual w1 tensor(737.3958)
# loss real tensor(926.0311)
# loss dual w1 tensor(2845.7754)
# loss real tensor(796.8580)
# loss dual w1 tensor(-862.7564)
# loss real tensor(926.7698)
# loss dual w1 tensor(3953.9150)
# loss real tensor(942.2006)
# loss dual w1 tensor(997.4286)
# loss real tensor(871.5945)
# loss dual w1 tensor(1413.4966)
# loss real tensor(756.0935)
# loss dual w1 tensor(552.3391)
# loss real tensor(858.3997)
# loss dual w1 tensor(549.3765)
# loss real tensor(888.6138)
# loss dual w1 tensor(3190.8462)
# loss real tensor(815.1229)
# loss dual w1 tensor(446.0441)
# loss real tensor(736.5121)
# loss dual w1 tensor(-105.6441)
# loss real tensor(944.7943)
# loss dual w1 tensor(-38.2047)
# loss real tensor(897.4922)
# loss dual w1 tensor(2879.7966)
# loss real tensor(896.8994)
# loss dual w1 tensor(314.1060)
# loss real tensor(923.1842)
# loss dual w1 tensor(1971.1018)
# loss real tensor(821.0800)
# loss dual w1 tensor(456.9731)
# loss real tensor(835.7309)
# loss dual w1 tensor(-228.3104)
# loss real tensor(825.3825)
# loss dual w1 tensor(2617.5696)
# loss real tensor(987.5962)
# loss dual w1 tensor(-37.7119)
# loss real tensor(935.6130)
# loss dual w1 tensor(1236.9159)
# loss real tensor(900.4357)
# loss dual w1 tensor(-1049.4163)
# loss real tensor(882.1089)
# loss dual w1 tensor(1013.8744)
# loss real tensor(814.3896)
# loss dual w1 tensor(3100.8313)
# loss real tensor(833.9980)
# loss dual w1 tensor(-551.7164)
# loss real tensor(905.7336)
# loss dual w1 tensor(688.7666)
# loss real tensor(899.0672)
# loss dual w1 tensor(270.6492)
# loss real tensor(899.1923)
# loss dual w1 tensor(-2016.8314)
# loss real tensor(887.4807)
# loss dual w1 tensor(629.8514)
# loss real tensor(944.5723)
# loss dual w1 tensor(1232.7026)
# loss real tensor(865.6122)
# loss dual w1 tensor(2133.6064)
# loss real tensor(920.5794)
# loss dual w1 tensor(509.1165)
# loss real tensor(859.6970)
# loss dual w1 tensor(-311.4259)
# loss real tensor(943.0386)
# loss dual w1 tensor(1476.0457)
# loss real tensor(846.0092)
# loss dual w1 tensor(4193.8496)
# loss real tensor(988.4954)
# loss dual w1 tensor(1831.4769)
# loss real tensor(923.5931)
# loss dual w1 tensor(-1749.3269)
# loss real tensor(923.7388)
# loss dual w1 tensor(260.5203)
# loss real tensor(877.3510)
# loss dual w1 tensor(-366.1290)
# loss real tensor(886.4883)
# loss dual w1 tensor(2339.1814)
# loss real tensor(842.4099)
# loss dual w1 tensor(3131.5803)
# loss real tensor(906.5634)
# loss dual w1 tensor(-1752.0776)
# loss real tensor(827.4288)
# loss dual w1 tensor(-616.4874)
# loss real tensor(830.0700)
# loss dual w1 tensor(-291.2634)
# loss real tensor(933.2729)
# loss dual w1 tensor(220.0023)
# loss real tensor(959.6099)
# loss dual w1 tensor(781.6940)
# loss real tensor(869.5642)
# loss dual w1 tensor(1460.9927)
# loss real tensor(864.5260)
# loss dual w1 tensor(13.6484)
# loss real tensor(909.0324)
# loss dual w1 tensor(976.3232)
# loss real tensor(926.7423)
# loss dual w1 tensor(-1956.9724)
# loss real tensor(883.8824)
# loss dual w1 tensor(1492.1218)
# loss real tensor(895.7709)
# loss dual w1 tensor(1893.4169)
# loss real tensor(929.1777)
# loss dual w1 tensor(-1263.9995)
# loss real tensor(850.4852)
# loss dual w1 tensor(1601.4314)
# loss real tensor(877.9001)
# loss dual w1 tensor(1452.0532)
# loss real tensor(937.1794)
# loss dual w1 tensor(-168.9744)
# loss real tensor(838.6381)
# loss dual w1 tensor(-1276.5828)
# loss real tensor(853.2363)
# loss dual w1 tensor(-602.1324)
# loss real tensor(828.6047)
# loss dual w1 tensor(-1542.3413)
# loss real tensor(870.0219)
# loss dual w1 tensor(463.2411)
# loss real tensor(881.7859)
# loss dual w1 tensor(-383.2979)
# loss real tensor(871.6672)
# loss dual w1 tensor(1121.8702)
# loss real tensor(980.3887)
# loss dual w1 tensor(2554.8975)
# loss real tensor(891.1123)
# loss dual w1 tensor(-1453.5552)
# loss real tensor(945.1366)
# loss dual w1 tensor(-480.1524)
# loss real tensor(864.8369)
# loss dual w1 tensor(2043.1075)
# loss real tensor(995.6228)
# loss dual w1 tensor(685.4587)
# loss real tensor(952.4675)
# loss dual w1 tensor(189.8583)
# loss real tensor(878.9968)
# loss dual w1 tensor(620.6727)
# loss real tensor(956.4384)
# loss dual w1 tensor(-507.2283)
# loss real tensor(872.0812)
# loss dual w1 tensor(1036.9006)
# loss real tensor(823.7290)
# loss dual w1 tensor(-1525.2076)
# loss real tensor(815.3925)
# loss dual w1 tensor(-888.6035)
# loss real tensor(920.0392)
# loss dual w1 tensor(-1005.2669)
# loss real tensor(842.2819)
# loss dual w1 tensor(912.5568)
# loss real tensor(921.2916)
# loss dual w1 tensor(-741.6934)
# loss real tensor(907.3401)
# loss dual w1 tensor(2538.1379)
# loss real tensor(981.2363)
# loss dual w1 tensor(1675.4011)
# loss real tensor(851.5450)
# loss dual w1 tensor(976.7611)
# loss real tensor(880.8629)
# loss dual w1 tensor(1946.7413)
# loss real tensor(901.5668)
# loss dual w1 tensor(754.1682)
# loss real tensor(861.1923)
# loss dual w1 tensor(378.5278)
# loss real tensor(919.4150)
# loss dual w1 tensor(1380.2869)
# loss real tensor(812.8454)
# loss dual w1 tensor(1652.2469)
# loss real tensor(866.6193)
# loss dual w1 tensor(259.7709)
# loss real tensor(795.5059)
# loss dual w1 tensor(3614.0876)
# loss real tensor(895.4425)
# loss dual w1 tensor(1093.6138)
# loss real tensor(787.1679)
# loss dual w1 tensor(970.8093)
# loss real tensor(911.8309)
# loss dual w1 tensor(-1009.2726)
# loss real tensor(937.4936)
# loss dual w1 tensor(969.7207)
# loss real tensor(916.1602)
# loss dual w1 tensor(1470.2490)
# loss real tensor(848.0961)
# loss dual w1 tensor(265.5752)
# loss real tensor(862.9030)
# loss dual w1 tensor(1666.7046)
# loss real tensor(974.3820)
# loss dual w1 tensor(2256.9319)
# loss real tensor(892.3080)
# loss dual w1 tensor(316.9948)
# loss real tensor(791.2657)
# loss dual w1 tensor(1300.5085)
# loss real tensor(876.3326)
# loss dual w1 tensor(4135.6011)
# loss real tensor(847.4131)
# loss dual w1 tensor(159.8686)
# loss real tensor(875.6602)
# loss dual w1 tensor(775.1983)
# loss real tensor(946.2030)
# loss dual w1 tensor(1189.9551)
# loss real tensor(938.3460)
# loss dual w1 tensor(-1522.8005)
# loss real tensor(939.1298)
# loss dual w1 tensor(2207.5156)
# loss real tensor(940.5921)
# loss dual w1 tensor(585.2966)
# loss real tensor(875.0321)
# loss dual w1 tensor(2638.6033)
# loss real tensor(849.3494)
# loss dual w1 tensor(2603.7107)
# loss real tensor(845.8839)
# loss dual w1 tensor(-252.2739)
# loss real tensor(939.9236)
# loss dual w1 tensor(-638.4112)
# loss real tensor(861.2585)
# loss dual w1 tensor(50.7441)
# loss real tensor(907.7719)
# loss dual w1 tensor(3407.6299)
# loss real tensor(945.9404)
# loss dual w1 tensor(1107.8604)
# loss real tensor(822.3303)
# loss dual w1 tensor(1169.3364)
# loss real tensor(942.7122)
# loss dual w1 tensor(1399.9000)
# loss real tensor(909.9270)
# loss dual w1 tensor(1245.2256)
# loss real tensor(946.0660)
# loss dual w1 tensor(893.0566)
# loss real tensor(858.6254)
# loss dual w1 tensor(3304.1301)
# loss real tensor(850.3882)
# loss dual w1 tensor(504.4098)
# loss real tensor(913.8290)
# loss dual w1 tensor(569.3208)
# loss real tensor(766.4518)
# loss dual w1 tensor(5052.8335)
# loss real tensor(876.1165)
# loss dual w1 tensor(-927.2542)
# loss real tensor(868.3088)
# loss dual w1 tensor(4618.7358)
# loss real tensor(833.8221)
# loss dual w1 tensor(-713.2179)
# loss real tensor(823.3356)
# loss dual w1 tensor(2385.7825)
# loss real tensor(1010.6584)
# loss dual w1 tensor(276.8017)
# loss real tensor(855.2888)
# loss dual w1 tensor(249.9327)
# loss real tensor(887.9026)
# loss dual w1 tensor(908.1870)
# loss real tensor(940.0320)
# loss dual w1 tensor(1138.8574)
# loss real tensor(935.9716)
# loss dual w1 tensor(3058.5776)
# loss real tensor(908.3680)
# loss dual w1 tensor(546.3973)
# loss real tensor(874.2720)
# loss dual w1 tensor(-834.1071)
# loss real tensor(859.0875)
# loss dual w1 tensor(-1017.4644)
# loss real tensor(858.8145)
# loss dual w1 tensor(2195.9165)
# loss real tensor(963.4794)
# loss dual w1 tensor(1388.1719)
# loss real tensor(784.6477)
# loss dual w1 tensor(1912.6755)
# loss real tensor(874.0193)
# loss dual w1 tensor(1220.9377)
# loss real tensor(960.2896)
# loss dual w1 tensor(224.8456)
# loss real tensor(888.5078)
# loss dual w1 tensor(-1094.7280)
# loss real tensor(875.1000)
# loss dual w1 tensor(2500.8870)
# loss real tensor(963.7843)
# loss dual w1 tensor(690.1907)
# loss real tensor(931.9727)
# loss dual w1 tensor(-841.8672)
# loss real tensor(891.4048)
# loss dual w1 tensor(364.6913)
# loss real tensor(806.5997)
# loss dual w1 tensor(1339.3813)
# loss real tensor(958.6115)
# loss dual w1 tensor(-360.1292)
# loss real tensor(901.0680)
# loss dual w1 tensor(-184.0897)
# loss real tensor(924.3979)
# loss dual w1 tensor(415.2174)
# loss real tensor(846.3004)
# loss dual w1 tensor(109.2730)
# loss real tensor(903.4970)
# loss dual w1 tensor(1271.2550)
# loss real tensor(902.8506)
# loss dual w1 tensor(3975.2056)
# loss real tensor(930.6071)
# loss dual w1 tensor(-3291.0342)
# loss real tensor(898.6965)
# loss dual w1 tensor(-1373.9309)
# loss real tensor(946.7990)
# loss dual w1 tensor(-1573.0667)
# loss real tensor(860.1374)
# loss dual w1 tensor(818.8431)
# loss real tensor(971.4004)
# loss dual w1 tensor(544.2426)
# loss real tensor(838.5573)
# loss dual w1 tensor(1560.9583)
# loss real tensor(971.8939)
# loss dual w1 tensor(-533.3627)
# loss real tensor(970.7885)
# loss dual w1 tensor(222.8179)
# loss real tensor(921.9587)
# loss dual w1 tensor(2060.9783)
# loss real tensor(956.5359)
# loss dual w1 tensor(481.2632)
# loss real tensor(874.1091)
# loss dual w1 tensor(3659.2351)
# loss real tensor(865.5049)
# loss dual w1 tensor(1442.8907)
# loss real tensor(913.1429)
# loss dual w1 tensor(1096.1299)
# loss real tensor(944.9562)
# loss dual w1 tensor(814.7129)
# loss real tensor(880.2967)
# loss dual w1 tensor(312.8908)
# loss real tensor(856.0256)
# loss dual w1 tensor(-93.1050)
# loss real tensor(859.9617)
# loss dual w1 tensor(1848.2639)
# loss real tensor(942.1787)
# loss dual w1 tensor(1684.4001)
# loss real tensor(987.7775)
# loss dual w1 tensor(2455.0920)
# loss real tensor(964.7616)
# loss dual w1 tensor(1243.3378)
# loss real tensor(893.7032)
# loss dual w1 tensor(-994.5665)
# loss real tensor(937.7792)
# loss dual w1 tensor(3611.6099)
# loss real tensor(891.7263)
# loss dual w1 tensor(2333.3938)
# loss real tensor(881.1322)
# loss dual w1 tensor(545.1026)
# loss real tensor(926.1711)
# loss dual w1 tensor(2620.0696)
# loss real tensor(784.5765)
# loss dual w1 tensor(2666.4553)
# loss real tensor(861.8550)
# loss dual w1 tensor(5195.2563)
# loss real tensor(909.2800)
# loss dual w1 tensor(276.0436)
# loss real tensor(802.8187)
# loss dual w1 tensor(2998.6328)
# loss real tensor(879.3655)
# loss dual w1 tensor(-585.2077)
# loss real tensor(767.4493)
# loss dual w1 tensor(-1462.9282)
# loss real tensor(985.2897)
# loss dual w1 tensor(266.3051)
# loss real tensor(770.4755)
# loss dual w1 tensor(1796.9646)
# loss real tensor(895.5642)
# loss dual w1 tensor(-612.8776)
# loss real tensor(845.8660)
# loss dual w1 tensor(3181.1521)
# loss real tensor(933.6649)
# loss dual w1 tensor(2024.7554)
# loss real tensor(876.7780)
# loss dual w1 tensor(999.2493)
# loss real tensor(821.4633)
# loss dual w1 tensor(3716.4458)
# loss real tensor(926.7682)
# loss dual w1 tensor(3856.1035)
# loss real tensor(906.5698)
# loss dual w1 tensor(983.9957)
# loss real tensor(783.9162)
# loss dual w1 tensor(2306.5767)
# loss real tensor(913.7670)
# loss dual w1 tensor(766.7347)
# loss real tensor(890.5114)
# loss dual w1 tensor(1347.8268)
# loss real tensor(924.9621)
# loss dual w1 tensor(799.0547)
# loss real tensor(808.0417)
# loss dual w1 tensor(-165.1552)
# loss real tensor(897.8490)
# loss dual w1 tensor(-1690.2462)
# loss real tensor(882.7354)
# loss dual w1 tensor(-927.7658)
# loss real tensor(899.8077)
# loss dual w1 tensor(-994.4803)
# loss real tensor(931.3997)
# loss dual w1 tensor(-952.4373)
# loss real tensor(899.7972)
# loss dual w1 tensor(1384.7935)
# loss real tensor(874.9171)
# loss dual w1 tensor(1251.1074)
# loss real tensor(865.9663)
# loss dual w1 tensor(1630.5249)
# loss real tensor(885.4168)
# loss dual w1 tensor(-2114.6509)
# loss real tensor(814.0958)
# loss dual w1 tensor(1970.2246)
# loss real tensor(921.0622)
# loss dual w1 tensor(577.9843)
# loss real tensor(912.2911)
# loss dual w1 tensor(-302.1889)
# loss real tensor(881.9798)
# loss dual w1 tensor(-903.4199)
# loss real tensor(897.3855)
# loss dual w1 tensor(-470.1852)
# loss real tensor(858.5207)
# loss dual w1 tensor(3466.2139)
# loss real tensor(922.4569)
# loss dual w1 tensor(-530.8661)
# loss real tensor(879.1672)
# loss dual w1 tensor(1240.8942)
# loss real tensor(933.3481)
# loss dual w1 tensor(3527.8784)
# loss real tensor(921.3168)
# loss dual w1 tensor(48.1312)
# loss real tensor(884.2973)
# loss dual w1 tensor(-1652.1372)
# loss real tensor(934.4136)
# loss dual w1 tensor(293.8113)
# loss real tensor(955.0084)
# loss dual w1 tensor(1483.5576)
# loss real tensor(905.4097)
# loss dual w1 tensor(-797.9124)
# loss real tensor(877.6946)
# loss dual w1 tensor(3036.3174)
# loss real tensor(928.8569)
# loss dual w1 tensor(1503.9318)
# loss real tensor(887.6183)
# loss dual w1 tensor(1570.3096)
# loss real tensor(827.2490)
# loss dual w1 tensor(-358.8611)
# loss real tensor(916.0852)
# loss dual w1 tensor(-714.8081)
# loss real tensor(924.0198)
# loss dual w1 tensor(94.4771)
# loss real tensor(888.8994)
# loss dual w1 tensor(-935.1564)
# loss real tensor(915.3055)
# loss dual w1 tensor(1350.0667)
# loss real tensor(882.8604)
# loss dual w1 tensor(1368.6350)
# loss real tensor(938.3190)
# loss dual w1 tensor(2210.3081)
# loss real tensor(866.9209)
# loss dual w1 tensor(1920.7169)
# loss real tensor(826.7647)
# loss dual w1 tensor(661.5747)
# loss real tensor(868.1652)
# loss dual w1 tensor(993.7341)
# loss real tensor(861.9255)
# loss dual w1 tensor(-704.6470)
# loss real tensor(929.0294)
# loss dual w1 tensor(3550.0757)
# loss real tensor(864.1364)
# loss dual w1 tensor(-536.9812)
# loss real tensor(869.0043)
# loss dual w1 tensor(1225.7899)
# loss real tensor(858.3814)
# loss dual w1 tensor(347.0410)
# loss real tensor(844.4504)
# loss dual w1 tensor(-140.0782)
# loss real tensor(931.2169)
# loss dual w1 tensor(5040.5171)
# loss real tensor(873.7310)
# loss dual w1 tensor(-478.2964)
# loss real tensor(852.7508)
# loss dual w1 tensor(1116.7712)
# loss real tensor(937.3550)
# loss dual w1 tensor(546.2234)
# loss real tensor(963.8997)
# loss dual w1 tensor(3741.0627)
# loss real tensor(814.1622)
# loss dual w1 tensor(-401.5197)
# loss real tensor(836.8514)
# loss dual w1 tensor(3236.3108)
# loss real tensor(849.6812)
# loss dual w1 tensor(2918.5601)
# loss real tensor(811.0743)
# loss dual w1 tensor(3009.7720)
# loss real tensor(893.1955)
# loss dual w1 tensor(1983.4683)
# loss real tensor(858.6460)
# loss dual w1 tensor(1883.6678)
# loss real tensor(938.8136)
# loss dual w1 tensor(224.8948)
# loss real tensor(853.0803)
# loss dual w1 tensor(1865.5724)
# loss real tensor(841.2698)
# loss dual w1 tensor(-70.4882)
# loss real tensor(926.2951)
# loss dual w1 tensor(335.7616)
# loss real tensor(923.3485)
# loss dual w1 tensor(682.9709)
# loss real tensor(883.2466)
# loss dual w1 tensor(-1553.2900)
# loss real tensor(901.3108)
# loss dual w1 tensor(1349.9829)
# loss real tensor(924.3423)
# loss dual w1 tensor(1714.3097)
# loss real tensor(937.7538)
# loss dual w1 tensor(1535.5178)
# loss real tensor(953.5147)
# loss dual w1 tensor(2441.1697)
# loss real tensor(895.2137)
# loss dual w1 tensor(1076.3782)
# loss real tensor(865.7339)
# loss dual w1 tensor(630.6959)
# loss real tensor(810.5599)
# loss dual w1 tensor(846.7283)
# loss real tensor(818.0108)
# loss dual w1 tensor(-1406.6628)
# loss real tensor(889.3831)
# loss dual w1 tensor(1172.6305)
# loss real tensor(806.1620)
# loss dual w1 tensor(270.3473)
# loss real tensor(858.0623)
# loss dual w1 tensor(-621.4592)
# loss real tensor(935.4293)
# loss dual w1 tensor(1833.8447)
# loss real tensor(911.8379)
# loss dual w1 tensor(2219.0239)
# loss real tensor(864.7280)
# loss dual w1 tensor(1900.7389)
# loss real tensor(895.4950)
# loss dual w1 tensor(1688.4183)
# loss real tensor(876.0328)
# loss dual w1 tensor(-821.7976)
# loss real tensor(816.2721)
# loss dual w1 tensor(1863.8464)
# loss real tensor(905.0287)
# loss dual w1 tensor(-1478.8405)
# loss real tensor(934.7094)
# loss dual w1 tensor(470.3326)
# loss real tensor(840.8766)
# loss dual w1 tensor(-655.4492)
# loss real tensor(940.5969)
# loss dual w1 tensor(290.1450)
# loss real tensor(844.8193)
# loss dual w1 tensor(10.1131)
# loss real tensor(871.2241)
# loss dual w1 tensor(-1423.9866)
# loss real tensor(841.6324)
# loss dual w1 tensor(822.3159)
# loss real tensor(943.6771)
# loss dual w1 tensor(1564.6483)
# loss real tensor(930.8782)
# loss dual w1 tensor(-720.0063)
# loss real tensor(858.3422)
# loss dual w1 tensor(3594.3550)
# loss real tensor(939.4899)
# loss dual w1 tensor(707.9711)
# loss real tensor(736.8551)
# loss dual w1 tensor(871.6749)
# loss real tensor(875.5435)
# loss dual w1 tensor(-1729.8696)
# loss real tensor(985.2408)
# loss dual w1 tensor(995.9335)
# loss real tensor(920.7153)
# loss dual w1 tensor(2125.2415)
# loss real tensor(896.2351)
# loss dual w1 tensor(1844.0265)
# loss real tensor(954.8564)
# loss dual w1 tensor(359.5759)
# loss real tensor(827.1060)
# loss dual w1 tensor(4086.2373)
# loss real tensor(723.2280)
# loss dual w1 tensor(1214.8281)
# loss real tensor(958.2027)
# loss dual w1 tensor(-1286.9216)
# loss real tensor(889.4233)
# loss dual w1 tensor(1242.4797)
# loss real tensor(929.3434)
# loss dual w1 tensor(3572.9307)
# loss real tensor(877.8659)
# loss dual w1 tensor(2462.3413)
# loss real tensor(865.4909)
# loss dual w1 tensor(4321.8696)
# loss real tensor(879.8963)
# loss dual w1 tensor(974.5620)
# loss real tensor(869.3545)
# loss dual w1 tensor(749.6439)
# loss real tensor(830.4197)
# loss dual w1 tensor(1606.9854)
# loss real tensor(912.7789)
# loss dual w1 tensor(-477.0536)
# loss real tensor(964.9347)
# loss dual w1 tensor(-432.9992)
# loss real tensor(860.4871)
# loss dual w1 tensor(815.7286)
# loss real tensor(874.0236)
# loss dual w1 tensor(-1850.6411)
# loss real tensor(882.3718)
# loss dual w1 tensor(1703.7820)
# loss real tensor(927.8303)
# loss dual w1 tensor(-553.0240)
# loss real tensor(837.8764)
# loss dual w1 tensor(590.1883)
# loss real tensor(960.0894)
# loss dual w1 tensor(658.1159)
# loss real tensor(933.9049)
# loss dual w1 tensor(2340.3296)
# loss real tensor(770.5136)
# loss dual w1 tensor(342.5714)
# loss real tensor(847.1486)
# loss dual w1 tensor(-1301.7261)
# loss real tensor(823.6094)
# loss dual w1 tensor(-259.1957)
# loss real tensor(893.6493)
# loss dual w1 tensor(-531.7457)
# loss real tensor(840.2942)
# loss dual w1 tensor(2116.0925)
# loss real tensor(922.0970)
# loss dual w1 tensor(-789.8347)
# loss real tensor(914.3530)
# loss dual w1 tensor(-73.7406)
# loss real tensor(917.6423)
# loss dual w1 tensor(-1555.6250)
# loss real tensor(929.4850)
# loss dual w1 tensor(1407.5809)
# loss real tensor(879.3428)
# loss dual w1 tensor(1602.6443)
# loss real tensor(838.8841)
# loss dual w1 tensor(847.9175)
# loss real tensor(843.1152)
# loss dual w1 tensor(1449.7368)
# loss real tensor(901.4277)
# loss dual w1 tensor(-1031.7845)
# loss real tensor(918.8398)
# loss dual w1 tensor(26.1263)
# loss real tensor(915.1542)
# loss dual w1 tensor(-2649.5693)
# loss real tensor(852.7054)
# loss dual w1 tensor(1896.4719)
# loss real tensor(898.0541)
# loss dual w1 tensor(-1403.0471)
# loss real tensor(885.2161)
# loss dual w1 tensor(1513.6877)
# loss real tensor(761.6337)
# loss dual w1 tensor(1128.8213)
# loss real tensor(958.6092)
# loss dual w1 tensor(753.1927)
# loss real tensor(942.4635)
# loss dual w1 tensor(1218.9978)
# loss real tensor(874.4191)
# loss dual w1 tensor(589.1356)
# loss real tensor(891.8385)
# loss dual w1 tensor(498.5856)
# loss real tensor(844.7914)
# loss dual w1 tensor(1548.6306)
# loss real tensor(916.9685)
# loss dual w1 tensor(912.6218)
# loss real tensor(965.8642)
# loss dual w1 tensor(1290.4727)
# loss real tensor(878.4698)
# loss dual w1 tensor(321.1390)
# loss real tensor(885.7905)
# loss dual w1 tensor(80.5778)
# loss real tensor(902.2839)
# loss dual w1 tensor(1331.9937)
# loss real tensor(940.3103)
# loss dual w1 tensor(-113.4960)
# loss real tensor(865.8173)
# loss dual w1 tensor(-933.4933)
# loss real tensor(922.7210)
# loss dual w1 tensor(863.8622)
# loss real tensor(921.0997)
# loss dual w1 tensor(-1188.9551)
# loss real tensor(928.4014)
# loss dual w1 tensor(323.1552)
# loss real tensor(887.7577)
# loss dual w1 tensor(2974.2512)
# loss real tensor(883.9894)
# loss dual w1 tensor(-1016.2682)
# loss real tensor(882.3743)
# loss dual w1 tensor(-189.9167)
# loss real tensor(869.0286)
# loss dual w1 tensor(2125.8892)
# loss real tensor(931.8088)
# loss dual w1 tensor(2299.8826)
# loss real tensor(772.4595)
# loss dual w1 tensor(2436.7205)
# loss real tensor(913.2313)
# loss dual w1 tensor(268.7518)
# loss real tensor(912.8963)
# loss dual w1 tensor(2794.5034)
# loss real tensor(967.6465)
# loss dual w1 tensor(552.2407)
# loss real tensor(858.7518)
# loss dual w1 tensor(817.2969)
# loss real tensor(892.3607)
# loss dual w1 tensor(-1866.9642)
# loss real tensor(877.0533)
# loss dual w1 tensor(-2048.0732)
# loss real tensor(961.0398)
# loss dual w1 tensor(1491.1941)
# loss real tensor(879.3496)
# loss dual w1 tensor(581.2012)
# loss real tensor(841.7015)
# loss dual w1 tensor(551.7410)
# loss real tensor(853.8532)
# loss dual w1 tensor(802.3630)
# loss real tensor(911.4608)
# loss dual w1 tensor(824.8873)
# loss real tensor(862.6456)
# loss dual w1 tensor(-228.4151)
# loss real tensor(892.2987)
# loss dual w1 tensor(1026.2998)
# loss real tensor(896.4536)
# loss dual w1 tensor(1455.2166)
# loss real tensor(953.6317)
# loss dual w1 tensor(741.9305)
# loss real tensor(872.9803)
# loss dual w1 tensor(644.3036)
# loss real tensor(838.1922)
# loss dual w1 tensor(2608.4202)
# loss real tensor(895.2648)
# loss dual w1 tensor(-1905.8198)
# loss real tensor(855.6347)
# loss dual w1 tensor(1953.3688)
# loss real tensor(876.5287)
# loss dual w1 tensor(1689.4008)
# loss real tensor(912.2941)
# loss dual w1 tensor(-526.3829)
# loss real tensor(880.4103)
# loss dual w1 tensor(2342.7742)
# loss real tensor(958.9361)
# loss dual w1 tensor(-2748.5405)
# loss real tensor(849.0575)
# loss dual w1 tensor(1010.2639)
# loss real tensor(852.2031)
# loss dual w1 tensor(2183.9126)
# loss real tensor(916.2112)
# loss dual w1 tensor(4017.9238)
# loss real tensor(895.4072)
# loss dual w1 tensor(3915.3257)
# loss real tensor(871.4079)
# loss dual w1 tensor(1848.1217)
# loss real tensor(938.9232)
# loss dual w1 tensor(2431.7461)
# loss real tensor(872.5952)
# loss dual w1 tensor(-2437.0852)
# loss real tensor(807.3813)
# loss dual w1 tensor(3018.7720)
# loss real tensor(829.0772)
# loss dual w1 tensor(-1559.4187)
# loss real tensor(941.8625)
# loss dual w1 tensor(25.6600)
# loss real tensor(863.6390)
# loss dual w1 tensor(896.0439)
# loss real tensor(933.9123)
# loss dual w1 tensor(331.3642)
# loss real tensor(814.6936)
# loss dual w1 tensor(1187.1133)
# loss real tensor(891.9230)
# loss dual w1 tensor(1928.1423)
# loss real tensor(889.6146)
# loss dual w1 tensor(-941.8666)
# loss real tensor(887.7620)
# loss dual w1 tensor(-670.7715)
# loss real tensor(838.8044)
# loss dual w1 tensor(-46.1040)
# loss real tensor(880.0532)
# loss dual w1 tensor(461.4135)
# loss real tensor(903.1995)
# loss dual w1 tensor(389.6683)
# loss real tensor(882.2562)
# loss dual w1 tensor(2020.3628)
# loss real tensor(853.8140)
# loss dual w1 tensor(1584.4395)
# loss real tensor(903.1232)
# loss dual w1 tensor(1145.2262)
# loss real tensor(819.2645)
# loss dual w1 tensor(4932.1709)
# loss real tensor(892.4120)
# loss dual w1 tensor(1534.8280)
# loss real tensor(877.2649)
# loss dual w1 tensor(1276.7917)
# loss real tensor(935.0712)
# loss dual w1 tensor(-61.7291)
# loss real tensor(863.5325)
# loss dual w1 tensor(2278.0500)
# loss real tensor(934.7801)
# loss dual w1 tensor(2557.5637)
# loss real tensor(801.2490)
# loss dual w1 tensor(1626.6191)
# loss real tensor(906.2573)
# loss dual w1 tensor(508.0396)
# loss real tensor(775.8905)
# loss dual w1 tensor(1801.5557)
# loss real tensor(899.1040)
# loss dual w1 tensor(604.6852)
# loss real tensor(882.8205)
# loss dual w1 tensor(417.6818)
# loss real tensor(948.9703)
# loss dual w1 tensor(1449.1646)
# loss real tensor(899.3026)
# loss dual w1 tensor(1033.3154)
# loss real tensor(910.6501)
# loss dual w1 tensor(1913.2761)
# loss real tensor(924.4393)
# loss dual w1 tensor(3126.9524)
# loss real tensor(829.4603)
# loss dual w1 tensor(-715.2953)
# loss real tensor(902.4423)
# loss dual w1 tensor(1208.2249)
# loss real tensor(877.7002)
# loss dual w1 tensor(1991.0825)
# loss real tensor(886.7950)
# loss dual w1 tensor(-252.0585)
# loss real tensor(887.6593)
# loss dual w1 tensor(108.6454)
# loss real tensor(890.1226)
# loss dual w1 tensor(558.3938)
# loss real tensor(882.0215)
# loss dual w1 tensor(-906.5115)
# loss real tensor(875.1909)
# loss dual w1 tensor(1572.5146)
# loss real tensor(835.8826)
# loss dual w1 tensor(5726.4126)
# loss real tensor(890.5214)
# loss dual w1 tensor(570.3686)
# loss real tensor(858.1546)
# loss dual w1 tensor(349.0943)
# loss real tensor(834.9420)
# loss dual w1 tensor(437.2096)
# loss real tensor(853.0742)
# loss dual w1 tensor(1689.6642)
# loss real tensor(897.8939)
# loss dual w1 tensor(378.9488)
# loss real tensor(930.4536)
# loss dual w1 tensor(2112.4600)
# loss real tensor(910.1002)
# loss dual w1 tensor(-974.9260)
# loss real tensor(800.7457)
# loss dual w1 tensor(2758.3069)
# loss real tensor(891.3416)
# loss dual w1 tensor(2577.0974)
# loss real tensor(926.5787)
# loss dual w1 tensor(-945.9840)
# loss real tensor(895.6851)
# loss dual w1 tensor(458.6478)
# loss real tensor(918.3534)
# loss dual w1 tensor(137.0988)
# loss real tensor(917.8304)
# loss dual w1 tensor(732.8168)
# loss real tensor(912.7841)
# loss dual w1 tensor(470.5650)
# loss real tensor(938.2603)
# loss dual w1 tensor(346.6293)
# loss real tensor(809.8856)
# loss dual w1 tensor(4661.2959)
# loss real tensor(982.5723)
# loss dual w1 tensor(2048.5625)
# loss real tensor(824.6118)
# loss dual w1 tensor(3887.0854)
# loss real tensor(921.6357)
# loss dual w1 tensor(1234.4296)
# loss real tensor(812.0580)
# loss dual w1 tensor(1721.4347)
# loss real tensor(812.9700)
# loss dual w1 tensor(1315.1957)
# loss real tensor(934.7922)
# loss dual w1 tensor(776.7354)
# loss real tensor(860.2722)
# loss dual w1 tensor(3138.5305)
# loss real tensor(816.1452)
# loss dual w1 tensor(-862.2123)
# loss real tensor(878.5642)
# loss dual w1 tensor(1528.9785)
# loss real tensor(917.2483)
# loss dual w1 tensor(-303.7006)
# loss real tensor(952.2015)
# loss dual w1 tensor(1636.3955)
# loss real tensor(888.5760)
# loss dual w1 tensor(2226.7244)
# loss real tensor(886.5462)
# loss dual w1 tensor(473.7482)
# loss real tensor(865.7645)
# loss dual w1 tensor(-2037.7667)
# loss real tensor(947.6288)
# loss dual w1 tensor(1703.7805)
# loss real tensor(955.5210)
# loss dual w1 tensor(847.9259)
# loss real tensor(895.2106)
# loss dual w1 tensor(2601.7581)
# loss real tensor(887.2685)
# loss dual w1 tensor(1743.5823)
# loss real tensor(908.0898)
# loss dual w1 tensor(3119.1436)
# loss real tensor(899.2719)
# loss dual w1 tensor(1639.2671)
# loss real tensor(957.1185)
# loss dual w1 tensor(582.4871)
# loss real tensor(838.2936)
# loss dual w1 tensor(-67.5307)
# loss real tensor(851.5246)
# loss dual w1 tensor(-802.8210)
# loss real tensor(830.8448)
# loss dual w1 tensor(2002.6841)
# loss real tensor(859.9872)
# loss dual w1 tensor(-717.4217)
# loss real tensor(862.8178)
# loss dual w1 tensor(1109.0894)
# loss real tensor(830.3481)
# loss dual w1 tensor(-1163.4268)
# loss real tensor(902.5397)
# loss dual w1 tensor(1105.1632)
# loss real tensor(882.5609)
# loss dual w1 tensor(2103.3860)
# loss real tensor(919.4694)
# loss dual w1 tensor(-114.8078)
# loss real tensor(863.6457)
# loss dual w1 tensor(-1175.9266)
# loss real tensor(839.0162)
# loss dual w1 tensor(966.2537)
# loss real tensor(944.1371)
# loss dual w1 tensor(1860.4146)
# loss real tensor(881.9730)
# loss dual w1 tensor(516.6422)
# loss real tensor(971.1251)
# loss dual w1 tensor(2185.9768)
# loss real tensor(786.4999)
# loss dual w1 tensor(2736.8135)
# loss real tensor(906.2378)
# loss dual w1 tensor(1650.9264)
# loss real tensor(834.3741)
# loss dual w1 tensor(896.8383)
# loss real tensor(860.4963)
# loss dual w1 tensor(486.0273)
# loss real tensor(889.6447)
# loss dual w1 tensor(2657.4717)
# loss real tensor(897.2833)
# loss dual w1 tensor(-223.4521)
# loss real tensor(851.4678)
# loss dual w1 tensor(1029.4087)
# loss real tensor(872.5612)
# loss dual w1 tensor(-1513.9874)
# loss real tensor(912.5956)
# loss dual w1 tensor(768.5408)
# loss real tensor(918.5806)
# loss dual w1 tensor(1210.6382)
# loss real tensor(821.4460)
# loss dual w1 tensor(-1205.7179)
# loss real tensor(865.2277)
# loss dual w1 tensor(883.8339)
# loss real tensor(869.1095)
# loss dual w1 tensor(4135.7920)
# loss real tensor(892.0735)
# loss dual w1 tensor(-1677.2472)
# loss real tensor(851.6677)
# loss dual w1 tensor(2832.3054)
# loss real tensor(914.4994)
# loss dual w1 tensor(-2669.2390)
# loss real tensor(927.1437)
# loss dual w1 tensor(86.7018)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 13
#      11 for epoch in range(num_epochs):
#      12     contador=0
# ---> 13     for images, labels in train_loader:
#      14         images = images.view(-1, input_size)
#      15         labels_onehot = torch.zeros(labels.size(0), output_size)
#
# File c:\Users\52333\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\dataloader.py:633, in _BaseDataLoaderIter.__next__(self)
#     630 if self._sampler_iter is None:
#     631     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     632     self._reset()  # type: ignore[call-arg]
# --> 633 data = self._next_data()
#     634 self._num_yielded += 1
#     635 if self._dataset_kind == _DatasetKind.Iterable and \
#     636         self._IterableDataset_len_called is not None and \
#     637         self._num_yielded > self._IterableDataset_len_called:
#
# File c:\Users\52333\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\dataloader.py:677, in _SingleProcessDataLoaderIter._next_data(self)
#     675 def _next_data(self):
#     676     index = self._next_index()  # may raise StopIteration
# --> 677     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     678     if self._pin_memory:
#     679         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\52333\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\_utils\fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File c:\Users\52333\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\_utils\fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File c:\Users\52333\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\datasets\mnist.py:145, in MNIST.__getitem__(self, index)
#     142 img = Image.fromarray(img.numpy(), mode="L")
#     144 if self.transform is not None:
# --> 145     img = self.transform(img)
#     147 if self.target_transform is not None:
#     148     target = self.target_transform(target)
#
# File c:\Users\52333\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\transforms\transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File c:\Users\52333\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\52333\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\transforms\transforms.py:277, in Normalize.forward(self, tensor)
#     269 def forward(self, tensor: Tensor) -> Tensor:
#     270     """
#     271     Args:
#     272         tensor (Tensor): Tensor image to be normalized.
#    (...)
#     275         Tensor: Normalized Tensor image.
#     276     """
# --> 277     return F.normalize(tensor, self.mean, self.std, self.inplace)
#
# File c:\Users\52333\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\transforms\functional.py:363, in normalize(tensor, mean, std, inplace)
#     360 if not isinstance(tensor, torch.Tensor):
#     361     raise TypeError(f"img should be Tensor Image. Got {type(tensor)}")
# --> 363 return F_t.normalize(tensor, mean=mean, std=std, inplace=inplace)
#
# File c:\Users\52333\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\transforms\_functional_tensor.py:922, in normalize(tensor, mean, std, inplace)
#     920 mean = torch.as_tensor(mean, dtype=dtype, device=tensor.device)
#     921 std = torch.as_tensor(std, dtype=dtype, device=tensor.device)
# --> 922 if (std == 0).any():
#     923     raise ValueError(f"std evaluated to zero after conversion to {dtype}, leading to division by zero.")
#     924 if mean.ndim == 1:
#
# KeyboardInterrupt:
